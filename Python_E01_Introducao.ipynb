# %%
#Sintaxe, Impressão e Operadores Aritméticos

# 1. Desenvolva um Algoritmo em Python que imprima a seguinte mensagem em linhas
# separadas:
# “É preciso fazer todos os algoritmos”
# “para aprender Python!!”
 
#2. Desenvolva um algoritmo em Python que armazene em uma variável o seguinte texto:
# “Instituto Federal de Educação, Ciência e Tecnologia do Rio Grande do Norte”. Logo em
# seguida, o algoritmo deve imprimir o texto armazenado na variável.


# 3. Desenvolva um algoritmo em Python que armazene um número real. O programa deverá
# imprimir logo em seguida (na mesma linha): &quot;O número armazenado é ____&quot;.

# 4. Desenvolva um algoritmo em Python que armazene o valor 30 em uma variável, e, logo
# em seguida, o algoritmo deverá imprimir o dobro do número armazenado.

# 5. Desenvolva um algoritmo em Python que armazene o numerador e o denominador de
# uma fração em duas variáveis distintas. Ao final, o programa deverá imprimir o resultado da
# operação.

# 6. Desenvolva um algoritmo em Python que armazene o seu peso em uma variável, e a sua
# altura em outra variável. O programa deve realizar o cálculo do IMC deste usuário através
# da seguinte fórmula: IMC = peso/altura2. Ao final, o valor do IMC deve ser impresso.

# 7. Desenvolva um algoritmo em Python que armazene 3 notas. O programa deverá calcular
# e imprimir ao final a média aritmética entre elas.

# 8. Desenvolva um algoritmo em Python que armazene um determinado valor em uma
# variável do tipo inteiro, e, logo em seguida, deverá imprimir 15% do valor armazenado.

# 9. Desenvolva um Algoritmo em Python que armazene o valor de um produto que você
# deseja comprar. Sabendo que a loja concede um desconto de 15%, o programa deverá
# imprimir o valor final do produto após o desconto.

# 10. Desenvolva um algoritmo em Python que armazene o valor do salário mínimo e o valor
# do seu salário. Ao final, o programa deverá imprimir quantos salários mínimos ele ganha.

Leitura de Dados

# 11. Refazer as atividades anteriores, e ao invés de armazenar os valores, solicitar ao
# usuário digitar.

Operadores Condicionais

# 12. Desenvolva um Algoritmo em Python que peça para o usuário digitar um número inteiro
# e salve em uma variável. O programa deve imprimir TRUE se o número for negativo, ou
# FALSE se for positivo.

# 13. Desenvolva um Algoritmo em Python que peça para o usuário digitar um número inteiro
# e salve em uma variável, e, logo em seguida, deverá imprimir TRUE se o número for par, ou
# FALSE se o número for ímpar.

# 14. Desenvolva um Algoritmo em Python que peça para o usuário digitar um número inteiro
# e salve em uma variável, e, logo em seguida, deverá imprimir TRUE se o número for
# divisível por 3, ou FALSE se o número não for divisível por 3.

Operadores Lógicos

# 15. Desenvolva um Algoritmo em Python que peça para o usuário digitar um número inteiro
# e salve em uma variável. Se o número armazenado for maior ou igual a 5 e menor que 50,
# imprimir TRUE; caso contrário, imprimir FALSE.

# 16. Desenvolva um Algoritmo em Python que peça para o usuário digitar um número inteiro
# e salve em uma variável. Se o número armazenado for um número positivo e menor que 10,
# imprimir TRUE; caso contrário, imprimir FALSE.

# 17. Desenvolva um Algoritmo em Python que peça para o usuário digitar um número inteiro
# e salve em uma variável. Se o número armazenado for um número maior que -10 e menor
# que 10, imprimir TRUE; caso contrário, imprimir FALSE.

# 18. Desenvolva um Algoritmo em Python que peça para o usuário digitar um número inteiro
# e salve em uma variável. Se o número armazenado for um número par e positivo, imprimir
# TRUE; caso contrário, imprimir FALSE.

# 19. Desenvolva um Algoritmo em Python que peça para o usuário digitar um número inteiro
# e salve em uma variável. Se o número armazenado for um número menor que 10 ou maior
# que 20, imprimir TRUE; caso contrário, imprimir FALSE.

# 20. Desenvolva um Algoritmo em Python que peça para o usuário digitar um número inteiro
# e salve em uma variável. Se o número armazenado for um número maior ou igual a 10 ou
# positivo, imprimir TRUE; caso contrário, imprimir FALSE.

# 21. Desenvolva um Algoritmo em Python que peça para o usuário digitar um número inteiro
# e salve em uma variável. Se o número armazenado for um número positivo, maior que 10 e
# menor que 20 imprimir TRUE; caso contrário, imprimir FALSE.

# %% [markdown]
# # Lista de Python

# %% [markdown]
# ### 1. Desenvolva um Algoritmo em Python que imprima a seguinte mensagem em linhas separadas:
# ### “É preciso fazer todos os algoritmos” “para aprender Python!!”
